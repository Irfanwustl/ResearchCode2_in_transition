# %%
import pandas as pd

# Load the dataframes
df1 = pd.read_excel('Supplementary Tables _102423_mineIRF.xlsx', sheet_name='irf')
df2 = pd.read_csv('PFS_Survival_hypo_hyper_combined.png.txt', sep='\t') #pd.read_csv('OS_Survival_hypo_hyper_combined.png.txt', sep='\t') #pd.read_csv('PFS_Survival_hypo_hyper_combined.png.txt', sep='\t') # so or pfs
ichordf  = pd.read_csv('results_prostate_default_plus_Y_summary.txt', sep='\t')
output = 'PFS_ichor_defaultplusY.txt'



#numeric_cols = ['Age ', 'Baseline PSA', 'Metagene', 'ECOG PS', 'Gleason total', 'Line of Therapy in Metastatic Setting','ctDNA level']
numeric_cols = ['Age ', 'Baseline PSA', 'Metagene', 'Gleason total', 'Line of Therapy in Metastatic Setting','ctDNA level','tumor_fraction']


ordinal_col = 'Metastatic Disease Burden'
#categorical_cols = []
categorical_cols = ['Race'] #,'AR/enhancer alterations detected in cfDNA']  # Replace these with your actual column names

time_col = 'PSA_progression (months)' #'OS months (from date of sample collection)'
event_col = 'PSA event (1= Progression)' #'OS Event'

# %%
print(df1.columns)
print(df2.columns)
#print(ichordf.columns)
# Out:
# Index(['Sample', 'Patient ID', 'Cohort', 'Timepoint',
#        'Genomic or epigenomic studies', 'Age ', 'Race', 'ECOG PS',
#        'Gleason total', 'Line of Therapy in Metastatic Setting',
#        '# lines of therapy prior to AR', 'Baseline PSA',
#        'Metastatic Disease Burden',
#        'Primary Therapy  (ADT 0, RT 1, Surgery 2, De novo 3)',
#        'AR-Directed Therapy', 'Progression Status', 'PFS (Months)',
#        'Survival Status', 'OS (Months)',
#        'AR/enhancer alterations detected in cfDNA', 'ctDNA level'],
#       dtype='object')
# Index(['Unnamed: 0', 'Unnamed: 1', 'PSA_progression (months)',
#        'PSA event (1= Progression)', 'Metagene'],
#       dtype='object')

# %%
df1.shape
# Out:
# (99, 21)

# %%
df1= pd.merge(df1, ichordf, left_on='Patient ID', right_on='sample_name')

# %%
df1['Race'] = df1['Race'].str.strip()
df1.head()
# Out:
#                            Sample Patient ID         Cohort      Timepoint  \
# 0  TU_W_4293-auto.bedgraph_rolled  TU_W_4293  Tulane cohort  Pre-treatment
# 1  TU_K_1928-auto.bedgraph_rolled  TU_K_1928  Tulane cohort  Pre-treatment
# 2  TU_P_9739-auto.bedgraph_rolled  TU_P_9739  Tulane cohort  Pre-treatment
# 3  TU_C_2412-auto.bedgraph_rolled  TU_C_2412  Tulane cohort  Pre-treatment
# 4  TU_B_5389-auto.bedgraph_rolled  TU_B_5389  Tulane cohort  Pre-treatment
#
#   Genomic or epigenomic studies  Age               Race  ECOG PS  \
# 0         EnhanceAR-Seq, EM-Seq    67  African American        0
# 1         EnhanceAR-Seq, EM-Seq    89         Caucasian  unknown
# 2         EnhanceAR-Seq, EM-Seq    87  African American  unknown
# 3         EnhanceAR-Seq, EM-Seq    78         Caucasian        0
# 4         EnhanceAR-Seq, EM-Seq    69         Caucasian        0
#
#   Gleason total  Line of Therapy in Metastatic Setting  ... OS (Months)  \
# 0             9                                      5  ...       Alive
# 1             9                                      3  ...       Alive
# 2             9                                      2  ...       Alive
# 3       unknown                                      3  ...       Alive
# 4             7                                      6  ...       Alive
#
#   AR/enhancer alterations detected in cfDNA ctDNA level Unnamed: 0  \
# 0                                        No    5.522580          2
# 1                                       Yes    3.793554         35
# 2                                       Yes    3.400799          1
# 3                                       Yes    4.590416         18
# 4                                        No    0.000000         22
#
#   sample_name tumor_fraction  ploidy  gender ChrY_coverage_fraction  \
# 0   TU_W_4293        0.19780   2.215    male               0.003169
# 1   TU_K_1928        0.13920   2.104    male               0.002230
# 2   TU_P_9739        0.05618   2.197    male               0.002666
# 3   TU_C_2412        0.13070   2.300    male               0.002784
# 4   TU_B_5389        0.00000   1.997    male               0.002784
#
#   ChrX_median_log_ratio
# 0               -0.8857
# 1               -1.0150
# 2               -0.9756
# 3               -0.9380
# 4               -1.0030
#
# [5 rows x 28 columns]

# %%
df1['Metastatic Disease Burden'].unique()
# Out:
# array(['low', 'high', 'Low', 'High', 'unknown'], dtype=object)

# %%
merged_df = pd.merge(df1, df2, left_on='Sample', right_on=df2.columns[1])
merged_df.set_index('Sample',inplace=True)

# %%
print(merged_df.shape)
print(df1['Race'].unique())
print(merged_df['Race'].unique())
merged_df.head()
# Out:
# (43, 32)
# ['African American' 'Caucasian']
# ['African American' 'Caucasian']
#                                Patient ID         Cohort      Timepoint  \
# Sample
# TU_W_4293-auto.bedgraph_rolled  TU_W_4293  Tulane cohort  Pre-treatment
# TU_K_1928-auto.bedgraph_rolled  TU_K_1928  Tulane cohort  Pre-treatment
# TU_P_9739-auto.bedgraph_rolled  TU_P_9739  Tulane cohort  Pre-treatment
# TU_C_2412-auto.bedgraph_rolled  TU_C_2412  Tulane cohort  Pre-treatment
# TU_B_5389-auto.bedgraph_rolled  TU_B_5389  Tulane cohort  Pre-treatment
#
#                                Genomic or epigenomic studies  Age   \
# Sample
# TU_W_4293-auto.bedgraph_rolled         EnhanceAR-Seq, EM-Seq    67
# TU_K_1928-auto.bedgraph_rolled         EnhanceAR-Seq, EM-Seq    89
# TU_P_9739-auto.bedgraph_rolled         EnhanceAR-Seq, EM-Seq    87
# TU_C_2412-auto.bedgraph_rolled         EnhanceAR-Seq, EM-Seq    78
# TU_B_5389-auto.bedgraph_rolled         EnhanceAR-Seq, EM-Seq    69
#
#                                             Race  ECOG PS Gleason total  \
# Sample
# TU_W_4293-auto.bedgraph_rolled  African American        0             9
# TU_K_1928-auto.bedgraph_rolled         Caucasian  unknown             9
# TU_P_9739-auto.bedgraph_rolled  African American  unknown             9
# TU_C_2412-auto.bedgraph_rolled         Caucasian        0       unknown
# TU_B_5389-auto.bedgraph_rolled         Caucasian        0             7
#
#                                 Line of Therapy in Metastatic Setting  \
# Sample
# TU_W_4293-auto.bedgraph_rolled                                      5
# TU_K_1928-auto.bedgraph_rolled                                      3
# TU_P_9739-auto.bedgraph_rolled                                      2
# TU_C_2412-auto.bedgraph_rolled                                      3
# TU_B_5389-auto.bedgraph_rolled                                      6
#
#                                # lines of therapy prior to AR  ...  \
# Sample                                                         ...
# TU_W_4293-auto.bedgraph_rolled                              2  ...
# TU_K_1928-auto.bedgraph_rolled                              1  ...
# TU_P_9739-auto.bedgraph_rolled                              1  ...
# TU_C_2412-auto.bedgraph_rolled                              0  ...
# TU_B_5389-auto.bedgraph_rolled                              2  ...
#
#                                tumor_fraction ploidy gender  \
# Sample
# TU_W_4293-auto.bedgraph_rolled        0.19780  2.215   male
# TU_K_1928-auto.bedgraph_rolled        0.13920  2.104   male
# TU_P_9739-auto.bedgraph_rolled        0.05618  2.197   male
# TU_C_2412-auto.bedgraph_rolled        0.13070  2.300   male
# TU_B_5389-auto.bedgraph_rolled        0.00000  1.997   male
#
#                                ChrY_coverage_fraction ChrX_median_log_ratio  \
# Sample
# TU_W_4293-auto.bedgraph_rolled               0.003169               -0.8857
# TU_K_1928-auto.bedgraph_rolled               0.002230               -1.0150
# TU_P_9739-auto.bedgraph_rolled               0.002666               -0.9756
# TU_C_2412-auto.bedgraph_rolled               0.002784               -0.9380
# TU_B_5389-auto.bedgraph_rolled               0.002784               -1.0030
#
#                                 Unnamed: 0_y                      Unnamed: 1  \
# Sample
# TU_W_4293-auto.bedgraph_rolled           Low  TU_W_4293-auto.bedgraph_rolled
# TU_K_1928-auto.bedgraph_rolled           Low  TU_K_1928-auto.bedgraph_rolled
# TU_P_9739-auto.bedgraph_rolled           Low  TU_P_9739-auto.bedgraph_rolled
# TU_C_2412-auto.bedgraph_rolled           Low  TU_C_2412-auto.bedgraph_rolled
# TU_B_5389-auto.bedgraph_rolled          High  TU_B_5389-auto.bedgraph_rolled
#
#                                PSA_progression (months)  \
# Sample
# TU_W_4293-auto.bedgraph_rolled                17.150310
# TU_K_1928-auto.bedgraph_rolled                29.470935
# TU_P_9739-auto.bedgraph_rolled                 9.002270
# TU_C_2412-auto.bedgraph_rolled                 4.829685
# TU_B_5389-auto.bedgraph_rolled                23.655600
#
#                                PSA event (1= Progression)  Metagene
# Sample
# TU_W_4293-auto.bedgraph_rolled                          1 -0.024080
# TU_K_1928-auto.bedgraph_rolled                          1  0.066863
# TU_P_9739-auto.bedgraph_rolled                          1  0.141508
# TU_C_2412-auto.bedgraph_rolled                          1 -0.155590
# TU_B_5389-auto.bedgraph_rolled                          1  0.380041
#
# [5 rows x 32 columns]

# %%
import numpy as np
import pandas as pd
from lifelines import CoxPHFitter

def perform_cox_regression_with_categoricals(df, time_col, event_col, numeric_cols, categorical_cols, ordinal_col=None):
    # Create a copy to avoid warnings
    df = df.copy()
    
    # List of columns to be included
    cols_to_include = [time_col, event_col] + numeric_cols + categorical_cols
    if ordinal_col:  # Only add ordinal_col if it's not None
        cols_to_include.append(ordinal_col)
        
    df = df[cols_to_include]

    # Replace 'unknown' or 'Unknown' with NaN values
    df.replace(["unknown", "Unknown"], np.nan, inplace=True)

    # Drop rows with NaN values
    df.dropna(inplace=True)

    # Replace ordinal values
    if ordinal_col:
        ordinal_mapping = {
            ordinal_col: {
                'low': 0,
                'high': 1,
                'Low': 0,
                'High': 1
            }
        }
        df.replace(ordinal_mapping, inplace=True)

    # Update the list of categorical columns to exclude the ordinal column
    categorical_cols = [col for col in categorical_cols if col != ordinal_col]
    
    # One-hot encoding the categorical variables
    df_encoded = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

    print(df_encoded.shape)
    display(df_encoded.head())

    # Fit the Cox regression model
    cph = CoxPHFitter()
    cph.fit(df_encoded, duration_col=time_col, event_col=event_col)

    # Return the model
    return cph



cph = perform_cox_regression_with_categoricals(merged_df, time_col, event_col, numeric_cols, categorical_cols, ordinal_col)
# Out:
# (40, 11)
# /var/folders/2f/dgzn6jc90s7b4k56lfc468600000gq/T/ipykernel_1286/776395785.py:17: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(["unknown", "Unknown"], np.nan, inplace=True)
# /var/folders/2f/dgzn6jc90s7b4k56lfc468600000gq/T/ipykernel_1286/776395785.py:32: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(ordinal_mapping, inplace=True)
#                                 PSA_progression (months)  \
# Sample
# TU_W_4293-auto.bedgraph_rolled                 17.150310
# TU_K_1928-auto.bedgraph_rolled                 29.470935
# TU_P_9739-auto.bedgraph_rolled                  9.002270
# TU_B_5389-auto.bedgraph_rolled                 23.655600
# TU_B_4587-auto.bedgraph_rolled                 38.998885
#
#                                 PSA event (1= Progression)  Age   \
# Sample
# TU_W_4293-auto.bedgraph_rolled                           1    67
# TU_K_1928-auto.bedgraph_rolled                           1    89
# TU_P_9739-auto.bedgraph_rolled                           1    87
# TU_B_5389-auto.bedgraph_rolled                           1    69
# TU_B_4587-auto.bedgraph_rolled                           1    78
#
#                                 Baseline PSA  Metagene  Gleason total  \
# Sample
# TU_W_4293-auto.bedgraph_rolled         22.25 -0.024080            9.0
# TU_K_1928-auto.bedgraph_rolled         77.20  0.066863            9.0
# TU_P_9739-auto.bedgraph_rolled         68.50  0.141508            9.0
# TU_B_5389-auto.bedgraph_rolled         11.50  0.380041            7.0
# TU_B_4587-auto.bedgraph_rolled         42.40  0.367979            9.0
#
#                                 Line of Therapy in Metastatic Setting  \
# Sample
# TU_W_4293-auto.bedgraph_rolled                                      5
# TU_K_1928-auto.bedgraph_rolled                                      3
# TU_P_9739-auto.bedgraph_rolled                                      2
# TU_B_5389-auto.bedgraph_rolled                                      6
# TU_B_4587-auto.bedgraph_rolled                                      3
#
#                                 ctDNA level  tumor_fraction  \
# Sample
# TU_W_4293-auto.bedgraph_rolled     5.522580         0.19780
# TU_K_1928-auto.bedgraph_rolled     3.793554         0.13920
# TU_P_9739-auto.bedgraph_rolled     3.400799         0.05618
# TU_B_5389-auto.bedgraph_rolled     0.000000         0.00000
# TU_B_4587-auto.bedgraph_rolled     0.613020         0.05726
#
#                                 Metastatic Disease Burden  Race_Caucasian
# Sample
# TU_W_4293-auto.bedgraph_rolled                          0           False
# TU_K_1928-auto.bedgraph_rolled                          1            True
# TU_P_9739-auto.bedgraph_rolled                          1           False
# TU_B_5389-auto.bedgraph_rolled                          0            True
# TU_B_4587-auto.bedgraph_rolled                          0           False

# %%
cph.print_summary()
# Out:
# <lifelines.CoxPHFitter: fitted with 40 total observations, 5 right-censored observations>
#              duration col = 'PSA_progression (months)'
#                 event col = 'PSA event (1= Progression)'
#       baseline estimation = breslow
#    number of observations = 40
# number of events observed = 35
#    partial log-likelihood = -88.92
#          time fit was run = 2024-05-20 14:17:56 UTC
#
# ---
#                                        coef exp(coef)  se(coef)  coef lower 95%  coef upper 95% exp(coef) lower 95% exp(coef) upper 95%
# covariate
# Age                                   -0.02      0.98      0.02           -0.06            0.03                0.94                1.03
# Baseline PSA                          -0.01      0.99      0.01           -0.02            0.01                0.98                1.01
# Metagene                               0.07      1.07      1.02           -1.93            2.07                0.14                7.91
# Gleason total                         -0.06      0.94      0.22           -0.48            0.36                0.62                1.44
# Line of Therapy in Metastatic Setting  0.33      1.39      0.14            0.06            0.61                1.06                1.83
# ctDNA level                           -0.03      0.97      0.03           -0.09            0.02                0.92                1.02
# tumor_fraction                         5.13    168.52      3.29           -1.31           11.57                0.27            1.06e+05
# Metastatic Disease Burden              0.64      1.90      0.52           -0.38            1.66                0.68                5.28
# Race_Caucasian                         0.06      1.06      0.53           -0.97            1.09                0.38                2.97
#
#                                        cmp to     z    p  -log2(p)
# covariate
# Age                                      0.00 -0.64 0.52      0.94
# Baseline PSA                             0.00 -0.68 0.50      1.01
# Metagene                                 0.00  0.07 0.95      0.08
# Gleason total                            0.00 -0.27 0.79      0.35
# Line of Therapy in Metastatic Setting    0.00  2.35 0.02      5.75
# ctDNA level                              0.00 -1.13 0.26      1.95
# tumor_fraction                           0.00  1.56 0.12      3.08
# Metastatic Disease Burden                0.00  1.23 0.22      2.19
# Race_Caucasian                           0.00  0.11 0.91      0.13
# ---
# Concordance = 0.75
# Partial AIC = 195.84
# log-likelihood ratio test = 22.02 on 9 df
# -log2(p) of ll-ratio test = 6.82

# %%
import numpy as np

# Assuming cph is your fitted CoxPHFitter model

# Extract model attributes
model_info = {
    'model': str(type(cph)),
    'duration col': cph.duration_col,
    'event col': cph.event_col,
    'baseline estimation': cph.baseline_estimation_method,
    'number of observations': cph._n_examples,
    'number of events observed': cph.event_observed.sum(),  # assuming the event column is binary
    'time fit was run': cph._time_fit_was_called
}

# Convert model_info to text
model_info_text = '\n'.join([f"{k}: {v}" for k, v in model_info.items()])

# Get cph.summary as a DataFrame
cph_summary_df = cph.summary

# Convert cph_summary to text
cph_summary_text = cph_summary_df.to_string()

# Additional metrics from cph.print_summary() output:
metrics = {
    'Concordance': cph.concordance_index_,
    'Partial AIC': cph.AIC_partial_,
    'log-likelihood ratio test': cph.log_likelihood_ratio_test().test_statistic,
    'negative log2(p) of ll-ratio test': -np.log2(cph.log_likelihood_ratio_test().p_value)
}

# Convert metrics to text
metrics_text = '\n'.join([f"{k}: {v}" for k, v in metrics.items()])

# Combine everything and save to a text file
with open(output, 'w') as file:
    file.write("== model_info ==\n")
    file.write(model_info_text)
    file.write("\n\n== cph.summary ==\n")
    file.write(cph_summary_text)
    file.write("\n\n== Additional Metrics ==\n")
    file.write(metrics_text)
cph_summary_df.to_csv(output+"_df.txt",sep='\t')
print("Data saved to output.txt")
# Out:
# Data saved to output.txt
