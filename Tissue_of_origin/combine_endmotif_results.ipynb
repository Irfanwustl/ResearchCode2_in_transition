# %%
import pandas as pd

# %%
f1 = '/Users/irf3irf3/Desktop/offline_workspace/data/tissue_of_origin/ArptRest_5_Samples_motifs_4.txt'
f2 = '/Users/irf3irf3/Desktop/offline_workspace/data/tissue_of_origin/EndMotif_frequency_withoutRest5.txt'

df1 = pd.read_csv(f1,sep ='\t',index_col = 0)
df2 = pd.read_csv(f2, sep = '\t', index_col = 0)

display(df1.head())
display (df2.head())
# Out:
#       dedup_Aligned_WBC1116_UC1_motifs.txt  \
# AAAA                               1363822
# AAAC                                442016
# AAAG                                554817
# AAAT                                739560
# AACA                                488506
#
#       dedup_Aligned_WBC1207_UC1_motifs.txt  \
# AAAA                               1649522
# AAAC                                492222
# AAAG                                629741
# AAAT                                808725
# AACA                                547214
#
#       dedup_Aligned_WBC1135_UC1_motifs.txt  \
# AAAA                               1477007
# AAAC                                505023
# AAAG                                641695
# AAAT                                801612
# AACA                                567452
#
#       dedup_Aligned_WBC1198_UC1_motifs.txt  \
# AAAA                               1699021
# AAAC                                516155
# AAAG                                672116
# AAAT                                888519
# AACA                                562754
#
#       dedup_Aligned_WBC1202_UC1_motifs.txt
# AAAA                                220132
# AAAC                                 62552
# AAAG                                 81528
# AAAT                                110969
# AACA                                 69428
#       PB-278_UC1_sorted_motifs.txt  PB046_UC1_sorted_motifs.txt  \
# AAAA                       1697863                      2047129
# AAAC                        558742                       655722
# AAAG                        718290                       842404
# AAAT                       1002696                      1147014
# AACA                        640921                       759313
#
#       NU90_sorted_motifs.txt  RCC013_UC1_sorted_motifs.txt  \
# AAAA                 2053065                       1694213
# AAAC                  645064                        545181
# AAAG                  823364                        722142
# AAAT                 1098857                        917790
# AACA                  711681                        622732
#
#       NU71_sorted_motifs.txt  PB206_UC1_sorted_motifs.txt  \
# AAAA                 1874416                      1873724
# AAAC                  612951                       597739
# AAAG                  799007                       789866
# AAAT                 1075842                      1064783
# AACA                  684254                       677695
#
#       PB-280_UC1_sorted_motifs.txt  PB-276_UC1_sorted_motifs.txt  \
# AAAA                       1921580                       1652556
# AAAC                        606259                        544355
# AAAG                        792731                        692573
# AAAT                       1089432                        962189
# AACA                        671315                        626294
#
#       PB-305_UC1_sorted_motifs.txt  NU75_sorted_motifs.txt  ...  \
# AAAA                       1798992                 2792628  ...
# AAAC                        597292                  887600  ...
# AAAG                        752361                 1144903  ...
# AAAT                        978963                 1546633  ...
# AACA                        682286                 1000480  ...
#
#       WBC1222_UC1.dup_mk_motifs.txt  BC020_UC1.dup_mk_motifs.txt  \
# AAAA                        3387457                      4008682
# AAAC                         764229                      1109904
# AAAG                         982137                      1451558
# AAAT                        1085110                      1954151
# AACA                         935029                      1242647
#
#       WBC1196_UC1.dup_mk_motifs.txt  WBC1111_UC1.dup_mk_motifs.txt  \
# AAAA                        4443565                        3525488
# AAAC                        1278700                        1011524
# AAAG                        1638985                        1288801
# AAAT                        2228700                        1779818
# AACA                        1491640                        1197716
#
#       WBC1188_UC1.dup_mk_motifs.txt  BC016_UC1.dup_mk_motifs.txt  \
# AAAA                        3312042                      5670317
# AAAC                         950838                      1407264
# AAAG                        1283328                      1895845
# AAAT                        1614284                      2389220
# AACA                        1126611                      1728622
#
#       WBC1309_UC1.dup_mk_motifs.txt  WBC1304_UC1.dup_mk_motifs.txt  \
# AAAA                        3231885                        3880230
# AAAC                        1012539                        1127552
# AAAG                        1325801                        1488290
# AAAT                        1755192                        1912909
# AACA                        1152911                        1377830
#
#       WBC1322_UC1.dup_mk_motifs.txt  BC011_UC1.dup_mk_motifs.txt
# AAAA                        7808827                      3840687
# AAAC                        2241726                      1107479
# AAAG                        2918270                      1468987
# AAAT                        3622751                      1674478
# AACA                        2690625                      1398048
#
# [5 rows x 201 columns]

# %%
df1.columns = df1.columns.str.replace('dedup_Aligned_', '')
display(df1.head())
# Out:
#       WBC1116_UC1_motifs.txt  WBC1207_UC1_motifs.txt  WBC1135_UC1_motifs.txt  \
# AAAA                 1363822                 1649522                 1477007
# AAAC                  442016                  492222                  505023
# AAAG                  554817                  629741                  641695
# AAAT                  739560                  808725                  801612
# AACA                  488506                  547214                  567452
#
#       WBC1198_UC1_motifs.txt  WBC1202_UC1_motifs.txt
# AAAA                 1699021                  220132
# AAAC                  516155                   62552
# AAAG                  672116                   81528
# AAAT                  888519                  110969
# AACA                  562754                   69428

# %%
print(df1.shape)
print(df2.shape)
# Out:
# (256, 5)
# (256, 201)

# %%
df_merged = df1.join(df2, how='inner')  # 'inner' ensures only matching index entries are kept


df_merged = df_merged.drop(columns=['WBC1320_UC1b_sorted_motifs.txt'])


print(df_merged.shape)
display(df_merged.head())
# Out:
# (256, 205)
#       WBC1116_UC1_motifs.txt  WBC1207_UC1_motifs.txt  WBC1135_UC1_motifs.txt  \
# AAAA                 1363822                 1649522                 1477007
# AAAC                  442016                  492222                  505023
# AAAG                  554817                  629741                  641695
# AAAT                  739560                  808725                  801612
# AACA                  488506                  547214                  567452
#
#       WBC1198_UC1_motifs.txt  WBC1202_UC1_motifs.txt  \
# AAAA                 1699021                  220132
# AAAC                  516155                   62552
# AAAG                  672116                   81528
# AAAT                  888519                  110969
# AACA                  562754                   69428
#
#       PB-278_UC1_sorted_motifs.txt  PB046_UC1_sorted_motifs.txt  \
# AAAA                       1697863                      2047129
# AAAC                        558742                       655722
# AAAG                        718290                       842404
# AAAT                       1002696                      1147014
# AACA                        640921                       759313
#
#       NU90_sorted_motifs.txt  RCC013_UC1_sorted_motifs.txt  \
# AAAA                 2053065                       1694213
# AAAC                  645064                        545181
# AAAG                  823364                        722142
# AAAT                 1098857                        917790
# AACA                  711681                        622732
#
#       NU71_sorted_motifs.txt  ...  WBC1222_UC1.dup_mk_motifs.txt  \
# AAAA                 1874416  ...                        3387457
# AAAC                  612951  ...                         764229
# AAAG                  799007  ...                         982137
# AAAT                 1075842  ...                        1085110
# AACA                  684254  ...                         935029
#
#       BC020_UC1.dup_mk_motifs.txt  WBC1196_UC1.dup_mk_motifs.txt  \
# AAAA                      4008682                        4443565
# AAAC                      1109904                        1278700
# AAAG                      1451558                        1638985
# AAAT                      1954151                        2228700
# AACA                      1242647                        1491640
#
#       WBC1111_UC1.dup_mk_motifs.txt  WBC1188_UC1.dup_mk_motifs.txt  \
# AAAA                        3525488                        3312042
# AAAC                        1011524                         950838
# AAAG                        1288801                        1283328
# AAAT                        1779818                        1614284
# AACA                        1197716                        1126611
#
#       BC016_UC1.dup_mk_motifs.txt  WBC1309_UC1.dup_mk_motifs.txt  \
# AAAA                      5670317                        3231885
# AAAC                      1407264                        1012539
# AAAG                      1895845                        1325801
# AAAT                      2389220                        1755192
# AACA                      1728622                        1152911
#
#       WBC1304_UC1.dup_mk_motifs.txt  WBC1322_UC1.dup_mk_motifs.txt  \
# AAAA                        3880230                        7808827
# AAAC                        1127552                        2241726
# AAAG                        1488290                        2918270
# AAAT                        1912909                        3622751
# AACA                        1377830                        2690625
#
#       BC011_UC1.dup_mk_motifs.txt
# AAAA                      3840687
# AAAC                      1107479
# AAAG                      1468987
# AAAT                      1674478
# AACA                      1398048
#
# [5 rows x 205 columns]

# %%
import os



# Extract the directory path from df1's file path
output_dir = os.path.dirname(f1)

output_file = os.path.join(output_dir, 'EndMotif_frequency_withRest5.txt')

df_merged.to_csv(output_file, sep='\t', index=True)  # Set index=False if you don't want to save the index
